# %%
# !jupyter nbconvert --to markdown perceptron_explore.ipynb
# Out:
# [NbConvertApp] WARNING | pattern 'perceptron_explore.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %% [markdown]
# Step 1.
#
# Import Libraries (PyTorch, Numpy and Pandas)

# %% [markdown]
# Step 2.
#
# Use Pandas to convert imported csv from URL into a Pandas DataFrame

# %% [markdown]
# Step 3.
#
# Delete all missing data from Dataframe using dropna function

# %% [markdown]
# Step 4.
#
# Separate Numerical Inputs from Output value (in this case: Species)

# %% [markdown]
# Step 5.
#
# Drop one of the Species Classifications in order to simplify algorithm into a Binary Classifier

# %% [markdown]
# Step 6.
#
# Convert Species Classification into numerical values using boolean functions, so that the augmented Species Matrix has values of only 0s and 1s

# %% [markdown]
# Step 7.
#
# Shuffle Data using Randperm functions as well as setting validation to 20% of the rows (each row is a data example, so 20% of data is validation)

# %% [markdown]
# Step 8.
#
# Standarize Input Data using Mean and Standard Deviation, so that the ranges are more consistent

# %% [markdown]
# Step 9.
#
# Convert Outputs to from values of 0 and 1 to values of -1 and 1 to better simulate Perceptron

# %% [markdown]
# Step 10.
#
# Initialize Weights by making an array of random values with the array size being the number of input columns + 1 to augment bias term

# %% [markdown]
# Step 11.
#
# Define Activation Function

# %% [markdown]
# Step 12.
#
# Create function for Forward Propagation, by taking dot product of inputs and weights, and returning the activation of that dot product

# %% [markdown]
# Step 13.
#
# Compute the $\Delta w$ and use it to update weights and bias

# %% [markdown]
# Step 14.
#
# Create an Accuracy Metric Function

# %% [markdown]
# Step 15.
#
# Recursively apply Forward Propagation and Weight Update Functions until either no updates are needed, or until the max amount of epochs are performed
